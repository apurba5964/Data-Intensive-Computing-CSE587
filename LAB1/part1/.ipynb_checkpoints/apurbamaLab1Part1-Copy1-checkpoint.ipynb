# %% [markdown]
# # Problem 1

# %%
sales1 <- c(12,14,16,29,30,45,19,20,16, 19, 34, 20)
sales2 <- rpois(12,34)
par(bg="cornsilk")
plot(sales1, col="blue", type="o", ylim=c(0,100), xlab="Month", ylab="Sales" )
title(main="Sales by Month")

lines(sales2, type="o", pch=22, lty=2, col="red")

grid(nx=NULL, ny=NULL)
legend("topright", inset=.05, c("Sales1","Sales2"), fill=c("blue","red"), horiz=TRUE)
# Out:
# Plot with title “Sales by Month”

# %% [markdown]
# #### Problem 1 Analysis: The second dataset generates random numbers which is based on Poisson Distribution, rpois method takes 2 arguments- 1)Number of observations we want to see and 2)The estimated rate of events for the distribution,this is also expressed as average events per period

# %% [markdown]
# # Problem 2

# %%
sales <-  read.table("salesdata.txt",header = T)
sales
barplot(as.matrix(sales), main="Sales Data", ylab= "Total",beside=T, col=rainbow(5))
# Out:
#    Sales1 Sales2
# 1  34     45
# 2  23     23
# 3  12     56
# 4  29     34
# 5  34     45
# 6  34     56
# 7  12     89
# 8  80     36
# 9  80     44
# 10 56     66
# 11 55     60
# 12 45     23
# Plot with title “Sales Data”

# %% [markdown]
# #### Problem 2 Analysis - The 2 sales data is being compared using the bar plot .This gives us a clear view about the sales distribution for both the dataset side by side

# %% [markdown]
# # Problem 3

# %%
fn<-boxplot(sales,col=c("orange","green"))$stats
text(1.45, fn[3,2], paste("Median =", fn[3,2]), adj=0, cex=.7)
text(0.45, fn[3,1],paste("Median =", fn[3,1]), adj=0, cex=.7)
grid(nx=NULL, ny=NULL)
# Out:
# plot without title

# %% [markdown]
# #### Problem 3 Analysis: A box plot is a way of  measuring the spread of the data points in the distribution having 4 quartiles.
# #### Sales 1 data : Range is  68 (low at 12 and high at 80) with median at 34.
# #### Sales 2 data : Range is  66 (low at 23 and high at 89) with median at 45

# %% [markdown]
# # Problem 4

# %%
fb1<-read.csv("FB.csv")

aapl1<-read.csv("AAPL.csv")

plot(aapl1$Adj.Close, col="blue", type="o", ylim=c(150,200), xlab="Days", ylab="Price" )
lines(fb1$Adj.Close, type="o", pch=22, lty=2, col="red")
legend("topright", inset=.05, c("Apple","Facebook"), fill=c("blue","red"), horiz=TRUE)

hist(aapl1$Adj.Close, col=rainbow(8))
# Out:
# plot without title
# Plot with title “Histogram of aapl1$Adj.Close”

# %% [markdown]
# #### Problem 4 Analysis: We can see from the line graph that adjusted close price of facebook shares was higher than apple .On 50th day they were almost same and at the end of 60 th day apple shares fell down to 160 and facebook shares price went up to 190.
# #### Apple adjusted close price was around 175 for 20 odd days .It fell to 160 on 60th day.

# %% [markdown]
# # Problem 5

# %%
data()

attach(cars)
head(cars)
summary(cars)
detach(cars)


library (help=datasets)
library(datasets)
head(uspop)
plot(uspop,col="blue",type="o")
grid(NA, 5, lwd = 2)

plot(uspop, log = "y", main = "uspop data", xlab = "Year",
     ylab = "U.S. Population (millions)")
# Out:
#   speed dist
# 1 4      2
# 2 4     10
# 3 7      4
# 4 7     22
# 5 8     16
# 6 9     10
#      speed           dist
#  Min.   : 4.0   Min.   :  2.00
#  1st Qu.:12.0   1st Qu.: 26.00
#  Median :15.0   Median : 36.00
#  Mean   :15.4   Mean   : 42.98
#  3rd Qu.:19.0   3rd Qu.: 56.00
#  Max.   :25.0   Max.   :120.00
# [1]  3.93  5.31  7.24  9.64 12.90 17.10
# plot without title
# Plot with title “uspop data”

# %% [markdown]
# #### The US population has a rising trend .It was around 3 million in 1800 which rose  close to 200 million in 1950

# %% [markdown]
# # Problem 6

# %%
library("ggmap")
library("maptools")
library(maps)
library(ggplot2)
register_google(key = "AIzaSyBIV-lwUgMJDjE4JDXFKRq11-u95RMauE0")

visited <- c("SFO", "Chennai", "London", "Melbourne", "Lima,Peru", "Johannesbury, SA")
ll.visited <- geocode(visited)
visit.x <- ll.visited$lon
visit.y <- ll.visited$lat
map("world", fill=TRUE, col="white", bg="lightblue", ylim=c(-60, 90), mar=c(0,0,0,0))
points(visit.x,visit.y, col="red", pch=36)
# Out:
# Loading required package: ggplot2
# Google's Terms of Service: https://cloud.google.com/maps-platform/terms/.
# Please cite ggmap if you use it! See citation("ggmap") for details.
# Loading required package: sp
# Checking rgeos availability: FALSE
#  	Note: when rgeos is not available, polygon geometry 	computations in maptools depend on gpclib,
#  	which has a restricted licence. It is disabled by default;
#  	to enable gpclib, type gpclibPermit()
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=SFO&key=xxx-lwUgMJDjE4JDXFKRq11-u95RMauE0
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Chennai&key=xxx-lwUgMJDjE4JDXFKRq11-u95RMauE0
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=London&key=xxx-lwUgMJDjE4JDXFKRq11-u95RMauE0
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Melbourne&key=xxx-lwUgMJDjE4JDXFKRq11-u95RMauE0
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Lima,Peru&key=xxx-lwUgMJDjE4JDXFKRq11-u95RMauE0
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Johannesbury,+SA&key=xxx-lwUgMJDjE4JDXFKRq11-u95RMauE0
# plot without title

# %%
visited <- c("SFO", "New York", "Buffalo", "Dallas", "TX")
ll.visited <- geocode(visited)
visit.x <- ll.visited$lon
visit.y <- ll.visited$lat
map("state", fill=TRUE, col=rainbow(50), bg="lightblue", mar=c(0,0,0,0))
points(visit.x,visit.y, col="yellow", pch=36)
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=SFO&key=xxx-lwUgMJDjE4JDXFKRq11-u95RMauE0
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=New+York&key=xxx-lwUgMJDjE4JDXFKRq11-u95RMauE0
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Buffalo&key=xxx-lwUgMJDjE4JDXFKRq11-u95RMauE0
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Dallas&key=xxx-lwUgMJDjE4JDXFKRq11-u95RMauE0
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=TX&key=xxx-lwUgMJDjE4JDXFKRq11-u95RMauE0
# plot without title

# %% [markdown]
# # Problem 7

# %%
attach(mtcars)
head(mtcars)
plot(mtcars[c(1,3,4,5,6)], main="MTCARS Data")
plot(mtcars[c(1,3,4,6)], main="MTCARS Data")
plot(mtcars[c(1,3,4,6)], col=rainbow(5),main="MTCARS Data")
detach(mtcars)
# Out:
# The following object is masked from package:ggplot2:
#
#     mpg
#                   mpg  cyl disp hp  drat wt    qsec  vs am gear carb
# Mazda RX4         21.0 6   160  110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag     21.0 6   160  110 3.90 2.875 17.02 0  1  4    4
# Datsun 710        22.8 4   108   93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive    21.4 6   258  110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout 18.7 8   360  175 3.15 3.440 17.02 0  0  3    2
# Valiant           18.1 6   225  105 2.76 3.460 20.22 1  0  3    1
# plot without title
# plot without title
# plot without title

# %%
attach(USArrests)
head(USArrests)
plot(USArrests[c(1,2,3)], main="USArrests Data")
plot(USArrests[c(1,2,3,4)], main="USArrests Data")
plot(USArrests[c(1,2,3,4)], col=rainbow(5),main="USArrests Data")
detach(USArrests)
# Out:
#            Murder Assault UrbanPop Rape
# Alabama    13.2   236     58       21.2
# Alaska     10.0   263     48       44.5
# Arizona     8.1   294     80       31.0
# Arkansas    8.8   190     50       19.5
# California  9.0   276     91       40.6
# Colorado    7.9   204     78       38.7
# plot without title
# plot without title
# plot without title

# %% [markdown]
# # Problem 8

# %%
ggplot(mtcars, aes(x=mpg, y=disp)) + geom_point()


options(scipen=999)  # turn-off scientific notation like 1e+48
library(ggplot2)
theme_set(theme_bw())  # pre-set the bw theme.
data("midwest", package = "ggplot2")
# Out:
# plot without title

# %%
# Scatterplot
gg <- ggplot(midwest, aes(x=area, y=poptotal)) + 
  geom_point(aes(col=state, size=popdensity)) + 
  geom_smooth(method="loess", se=F) + 
  xlim(c(0, 0.1)) + 
  ylim(c(0, 500000)) + 
  labs(subtitle="Area Vs Population", 
       y="Population", 
       x="Area", 
       title="Scatterplot", 
       caption = "Source: midwest")

plot(gg)
# Out:
# Warning message:
# “Removed 15 rows containing non-finite values (stat_smooth).”Warning message:
# “Removed 15 rows containing missing values (geom_point).”
# plot without title
