# %% [markdown]
# ### Apurba Mahanta
# ### UbitName : apurbama
# ### Person Number : 50288705
#
# ### Teammate :
# ### Sagnik Ghosh
# ### UbitName : sagnikgh
# ### Person Number : 50289151

# %% [markdown]
# ### 1) Influenza national summary (green and yellow chart)

# %%
flu_summary <- read.csv("Influenza_national_summary.csv")

library(ggplot2)
flu_summary
# Out:
#    Week   Total.A Total.B Percent.Positive.A Percent.Positive.B Total...Tested
# 1  201840  218     69      1.32              0.41               16492
# 2  201841  222     81      1.23              0.45               17980
# 3  201842  311     89      1.54              0.44               20128
# 4  201843  337     98      1.58              0.46               21302
# 5  201844  389     98      1.74              0.43               22281
# 6  201845  543     95      2.33              0.40               23304
# 7  201846  667     99      2.74              0.40               24288
# 8  201847  893     72      3.64              0.29               24511
# 9  201848  998    103      3.55              0.36               28063
# 10 201849 1658    147      5.74              0.50               28835
# 11 201850 3235    188      9.83              0.57               32892
# 12 201851 5282    179     13.84              0.46               38138
# 13 201852 6835    231     15.87              0.53               43057
# 14 201901 5212    135     11.85              0.30               43952
# 15 201902 4835    204     12.14              0.51               39808
# 16 201903 6310    166     15.76              0.41               40025
# 17 201904 7703    224     18.79              0.54               40975
#    X..Positive
# 1   1.74
# 2   1.68
# 3   1.98
# 4   2.04
# 5   2.18
# 6   2.73
# 7   3.15
# 8   3.93
# 9   3.92
# 10  6.25
# 11 10.40
# 12 14.31
# 13 16.41
# 14 12.16
# 15 12.65
# 16 16.17
# 17 19.34

# %%
# Create the data for the chart
A <- flu_summary$Total.A
B <- flu_summary$Total.B
M <- flu_summary$Week

data=data.frame(B,A)
colors <- c("green","yellow")

# Plot the bar chart 
#barplot(H,names.arg=M,xlab="Month",ylab="Revenue",col="yellow",
#main="Influenza national summary ",ylim=range(0,10000),space=0)


barplot(as.matrix(as.data.frame(t(data))),beside=F,xlab="Week",names.arg=M, col=colors,axis.lty="solid",
       ylim=c(0,10000),ylab="Number of positive specimens", main="Influenza Positive Tests Reports by Clinical Laboratories")
#legend("topright",rownames(t(data)),fill=colors,title="Influenza national summary")
par(new=T)
#plot(flu_summary$Percent.Positive.A,type = 'o')

plot(flu_summary$X..Positive, col="black", type="l", ylim=c(0,25), ylab="" ,xaxt="n",yaxt="n",
    xlab="")

# second y-axis
axis(4, cex.axis=0.6, tick=FALSE, adj =.04, line = -1.2)
mtext("Percent Positive", side=4, line=0.9)

par(new=T)
lines(flu_summary$Percent.Positive.A, col="#FF9933", type="l", lty=2,lwd=2, ylim=c(0,25), xlab="", ylab="" ,xaxt="n",yaxt="n")
par(new=T)
lines(flu_summary$Percent.Positive.B, col="green", type="l", lty=2,lwd=2, ylim=c(0,25), xlab="", ylab="" ,xaxt="n",yaxt="n")

legend("topright", bty="n", c("A","B"), fill=c("yellow","chartreuse3"), inset=c(.1,.001))
legend("topright", bty="n", c("Percent Positive","% Positive Flu A", "% Positive Flu A"), lty=c(1,2,2),lwd=c(1,2,2), col=c("black","darkgoldenrod2","chartreuse4"), inset=c(.1,.1))
# Out:
# Plot with title “Influenza Positive Tests Reports by Clinical Laboratories”

# %% [markdown]
# ### 2) Influenza Positive Tests Reported

# %%
positive <- read.csv("positive_test.csv")
positive
# Out:
#    Week   A.H3N2v. A..H1N1.pdm09 A.H3. A.unable.to.sub.type.
# 1  201840 0          29           11   0
# 2  201841 0          52           11   0
# 3  201842 0          51           21   0
# 4  201843 0          74           35   0
# 5  201844 0          82           23   0
# 6  201845 0         117           27   0
# 7  201846 0         147           40   0
# 8  201847 0         211           53   0
# 9  201848 0         316           63   0
# 10 201849 0         342           88   0
# 11 201850 0         641          161   0
# 12 201851 0        1024          195   0
# 13 201852 0        1127          222   0
# 14 201901 0        1048          249   0
# 15 201902 0        1278          201   0
# 16 201903 0        1235          291   0
# 17 201904 0        1125          358   0
#    A.Subtyping.not.performed. B  BVIC BYAM Total...Tested
# 1    7                         0  7   11    793
# 2    7                         5  3    5    898
# 3   13                         1  2   14   1086
# 4    3                         3  0   13   1089
# 5    2                         1  1    8   1217
# 6   14                         4  4    7   1306
# 7    9                         0  2    3   1393
# 8    9                         1  2    5   1101
# 9    9                         1  2   10   1672
# 10  14                         7  3    7   1628
# 11  16                         3  7    6   2068
# 12  78                         9 20    7   2416
# 13 102                        10 18    6   2283
# 14 161                         6  4   10   2542
# 15  47                         9  1   11   2897
# 16  38                         9 13   14   2742
# 17  46                        12 14    9   2474

# %%
# Create the data for the chart
A2 <- positive$A.Subtyping.not.performed
B2 <- positive$A..H1N1.pdm09
C2 <- positive$A.H3.
M2 <- positive$Week
data2=data.frame(B2,A2)
colors <- c("orange","yellow")



barplot(as.matrix(as.data.frame(t(data2))),beside=F,xlab="Week",names.arg=M2, col=colors,axis.lty="solid",
       ylim=range(0,1800),ylab="Number of positive specimens",main="Influenza Positive Tests Reports by Public Health Laboratories")


par(new=T)
barplot(positive$A.H3.,col="red",ylim=c(0,1800),xlab="Week",ylab="",names.arg=M2)

par(new=T)
barplot(positive$A.H3N2v.,col="purple",ylim=c(0,1800),xlab="Week",ylab="",names.arg=M2)


par(new=T)
barplot(positive$B,col="darkgreen",ylim=c(0,1800),xlab="Week",ylab="",names.arg=M2)

par(new=T)
barplot(positive$BVIC,col="chartreuse",ylim=c(0,1800),xlab="Week",ylab="",names.arg=M2)

par(new=T)
barplot(positive$BYAM,col="chartreuse4",ylim=c(0,1800),xlab="Week",ylab="",names.arg=M2)

legend("topright", bty="n", c("A (Subtyping not performed)","(H1N1)pdm09","A(H3N2)","H3N2v","B(lineage not performed)",
                             "B(Victoria Lineage)","B(Yamgata Lineage)"), fill=c("yellow","orange",
                                                                                "red","purple",
                                                                                "darkgreen","chartreuse"
                                                                                ,"chartreuse4"),inset=c(.1,.001))
# Out:
# Plot with title “Influenza Positive Tests Reports by Public Health Laboratories”

# %% [markdown]
# ### 3)Influenza-Like Illness (ILI) Activity Level Indicator Determined by Data Reported to ILINet
# ### 2018-19 Influenza Season Week 4 ending Jan 28, 2019

# %%
library("ggmap")
library("maptools")
library(maps)
library(ggplot2)
register_google(key = "AIzaSyBIV-lwUgMJDjE4JDXFKRq11-u95RMauE0")
# Out:
# Google's Terms of Service: https://cloud.google.com/maps-platform/terms/.
# Please cite ggmap if you use it! See citation("ggmap") for details.
# Loading required package: sp
# Checking rgeos availability: FALSE
#  	Note: when rgeos is not available, polygon geometry 	computations in maptools depend on gpclib,
#  	which has a restricted licence. It is disabled by default;
#  	to enable gpclib, type gpclibPermit()

# %%
heatmap <- read.csv("heatmap2.csv")
heatmap1 <- read.csv("heatmap1.csv")
heatmap2 <-  data.frame(heatmap1$STATENAME,heatmap1$ACTIVITY.LEVEL,heatmap1$ACTIVITY.LEVEL.LABEL)
heatmap2$heatmap1.ACTIVITY.LEVEL = as.numeric(substr(heatmap2$heatmap1.ACTIVITY.LEVEL,6,8))

x= aggregate(heatmap2$heatmap1.ACTIVITY.LEVEL, list(heatmap2$heatmap1.STATENAME), mean)
#x[,-1] <-round(x[,-1],0)
x[,-1] <-ceiling(x[,-1])
names(x)[names(x) == 'Group.1'] <- 'state'
names(x)[names(x) == 'x'] <- 'ACTIVITY.LEVEL'
x
# Out:
#    state                ACTIVITY.LEVEL
# 1  Alabama              7
# 2  Alaska               3
# 3  Arizona              5
# 4  Arkansas             4
# 5  California           3
# 6  Colorado             7
# 7  Connecticut          4
# 8  Delaware             2
# 9  District of Columbia 4
# 10 Florida              2
# 11 Georgia              8
# 12 Hawaii               2
# 13 Idaho                2
# 14 Illinois             3
# 15 Indiana              4
# 16 Iowa                 2
# 17 Kansas               4
# 18 Kentucky             5
# 19 Louisiana            7
# 20 Maine                2
# 21 Maryland             3
# 22 Massachusetts        4
# 23 Michigan             2
# 24 Minnesota            4
# 25 Mississippi          5
# 26 Missouri             3
# 27 Montana              2
# 28 Nebraska             5
# 29 Nevada               3
# 30 New Hampshire        3
# 31 New Jersey           6
# 32 New Mexico           5
# 33 New York             4
# 34 New York City        6
# 35 North Carolina       4
# 36 North Dakota         2
# 37 Ohio                 2
# 38 Oklahoma             6
# 39 Oregon               3
# 40 Pennsylvania         4
# 41 Puerto Rico          5
# 42 Rhode Island         3
# 43 South Carolina       6
# 44 South Dakota         2
# 45 Tennessee            2
# 46 Texas                5
# 47 Utah                 5
# 48 Vermont              3
# 49 Virgin Islands       2
# 50 Virginia             6
# 51 Washington           2
# 52 West Virginia        3
# 53 Wisconsin            3
# 54 Wyoming              3

# %%
#install.packages("usmap")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(usmap)
library(ggplot2)

cols = c("Level 10 High" = "firebrick4","Level 9 High" ="firebrick1","Level 8 High" ="orange",
         "Level 7 Moderate" ="goldenrod3","Level 6 Moderate" ="yellow","Level 5 Low" ="darkolivegreen1",
                                                "Level 4 Low" ="darkolivegreen4","Level 3 Minimal" ="chartreuse"
         ,"Level 2 Minimal" ="chartreuse3","Level 1 Minimal" ="chartreuse4")




plot_usmap(data = x, values = "ACTIVITY.LEVEL", labels = FALSE)+
 scale_fill_continuous(name = "ILI Activity Level",low ='green',high='red') + 
  theme(legend.position = "right")+labs(title = "A Seasonal Influenza Surveillance Report Prepared by the Influenza Division
Influenza-Like Illness (ILI) Activity Level Indicator Determined by Data Reported to ILINet \n 2018-19 season", subtitle = "")
#scale_fill_manual(name="ILI Activity Level", values=cols) + theme(legend.position = "right")
# Out:
# plot without title

# %%
data4 <- read.csv("heatmap2.csv")

library(usmap)
library(ggplot2)

state <- data4$STATENAME
level <- data4$ACTIVITY.LEVEL
dataframe <- data.frame(state, level)
p2 <- plot_usmap(data = dataframe, values = "level", lines = "black") + theme(legend.position = "right") + labs(title = "A Weekly Influenza Surveillance Report Prepared by the Influenza Division
Influenza-Like Illness (ILI) Activity Level Indicator Determined by Data Reported to ILINet \n  Current Week(Week 4 Jan 2019 )", subtitle = "") + 
    scale_fill_manual(name = "ILI Activity Level", 
    values = c("red3","orangered1","darkorange","goldenrod3","yellow","yellow3","green","green2","green3","green4","white"), 
    lab =c("Level 10 High","Level 9 High","Level 8 High","Level 7 Moderate","Level 6 Moderate","Level 5 Low","Level 4 Low","Level 3 Minimal","Level 2 Minimal","Level 1 Minimal","Insufficient Data"))
p2
# Out:
# plot without title

# %% [markdown]
# ### 4)Influenza-Associated Pediatric Mortality:

# %%
data6 <- read.csv("Weekly.csv")
df <- data.frame(weeknumber=data6$WEEK_NUMBER, prevweek=data6$PREVIOUS_WEEK_DEATHS, curweek=data6$CURRENT_WEEK_DEATHS)

for (i in 1:NROW(data6$WEEK_NUMBER))
    if(as.numeric(substr(data6$WEEK_NUMBER[i],6,7))%%10 == 0){
        data6$WEEK_NUMBER[i] <- data6$WEEK_NUMBER[i]
    }else{
        data6$WEEK_NUMBER[i] <- NA
    }

barplot(df$prevweek, col="green", ylim=c(0,30),main="Number of Influenza Associated Pediatric Deaths by Week of Death:
2015-16 season to present(Week 8 of 2019)",names.arg=data6$WEEK_NUMBER,las=2,yaxt='n',cex.names=0.6)


#bar <- barplot(d1, col="green", ylim=c(0,30))
#text(bar, d1, labels=d1)

#par(new=T)
#bar1 <- barplot(d2, col="blue", yaxt='n', ylim=c(0,30))

par(new=T)
barplot(df$curweek, col="blue", ylim=c(0,30))
#axis(1, at=df$weeknumber, labels=data6$WEEK_NUMBER, las=2, cex.axis=0.6, tick = FALSE, pos=1)

title(main="2015-2016", adj =.06, line = -6.5, cex.main=.9)
title(main="Number of Deaths", adj =.04, line = -7.8, cex.main=.7)
title(main="Reported = 94", adj =.06, line = -8.8, cex.main=.7)
#axis(1, at=dataframe$weeknumber, labels=dataframe$weeknumber)

title(main="2016-2017", adj =.34, line = -6.5, cex.main=.9)
title(main="Number of Deaths", adj =.33, line = -7.8, cex.main=.7)
title(main="Reported = 110", adj =.34, line = -8.8, cex.main=.7)

title(main="2017-2018", adj =.61, line = -6.5, cex.main=.9)
title(main="Number of Deaths", adj =.62, line = -7.8, cex.main=.7)
title(main="Reported = 185", adj =.62, line = -8.8, cex.main=.7)

title(main="2018-2019", adj =.89, line = -6.5, cex.main=.9)
title(main="Number of Deaths", adj =.93, line = -7.8, cex.main=.7)
title(main="Reported = 56", adj =.9, line = -8.8, cex.main=.7)

legend("topright", bty="n", c("Deaths reported previous week","Deaths reported current week")
       , fill=c("green","blue"))
# Out:
# Plot with title “Reported = 56”

# %% [markdown]
# ### 5) Pneumonia and Influenza (P&I) Mortality Surveillance:

# %%
library(grid)
mortality <- read.csv("Mortality.csv")

mortality$year_week <- paste(mortality$Year,mortality$Week)

# %%
data5 <- read.csv("NCHSData06.csv")
x <- as.vector(data5$Week)
y1 <- data5$Expected
y2 <- data5$Threshold
y3 <- data5$Percent

df <- data.frame(exp=data5$Expected, thrs=data5$Threshold, prs=data5$Percent, date=data5$Date, year=data5$Year, week=data5$Week)

for (i in 1:NROW(data5$Week))
    if(data5$Week[i]%%10 == 0){
        data5$Week[i] <- data5$Week[i]
    }else{
        data5$Week[i] <- NA
    }

plot(df$exp, xlab="Week", ylab="% of all death due to P&I", type="l", xaxt="n", ylim=c(4,12), lwd=2, las=1)
title(main=c(paste("Pneumonia and Influenza Mortality from"),
     paste("the National Center for Health Statistics Mortality Surveillance System")))
#title(main="Pneumonia and Influenza Mortality from \n
#the National Center for Health Statistics Mortality Surveillance System")

par(new=T, ps = 12, cex = 1, cex.main = 1)
p1 <- plot(df$thrs, xlab="Week", ylab="% of all death due to P&I", type="l", xaxt="n", ylim=c(4,12), lwd=2, las=1)
axis(1, at=df$date, label=df$year, pos=4.5, cex.axis=0.6, tick = FALSE)
#text(p1, labels = c("40","50","10","20","30","40","50","10","20","30","40","50","10","20","30","40","50","10","20","30","40","50"), srt = 45, adj = c(1,1.5), xpd = TRUE, cex=.9)

par(new=T, ps = 12, cex = 1, cex.main = 1)
p2 <- plot(df$prs, xlab="Week", ylab="% of all death due to P&I", type="l", col ="red", xaxt="n", ylim=c(4,12), lwd=2, las=1)
axis(1, at=df$date, label=data5$Week, pos=4, las=1, tick=FALSE, cex.axis=0.6)
#text(p2, labels = c("40","50","10","20","30","40","50","10","20","30","40","50","10","20","30","40","50","10","20","30","40","50"), srt = 45, adj = c(1,1.5), xpd = TRUE, cex=.9)


arrows(60, 5, 80, 7, col = "black")
legend(3,5.2,legend =c("Seasonal Baseline"), bty="n", cex= 0.8)
arrows(40, 9, 57, 7, col = "black")
legend(20,9.5,legend =c("Epidemic Threshold"), bty="n", cex= 0.8)

# %% [markdown]
# # SOLUTION 5
# ## Influenza national summary (green and yellow chart) -52 WEEKS

# %%
flu_summary_52 <- read.csv("FluViewPhase2Data/WHO_NREVSS_Clinical_Labs.csv")

flu_summary_52$YEAR_WEEK <- paste(flu_summary_52$YEAR,flu_summary_52$WEEK)
flu_summary_52$YEAR_WEEK <- gsub('\\s+', '', flu_summary_52$YEAR_WEEK)

# %%
# Create the data for the chart
A <- flu_summary_52$TOTAL.A
B <- flu_summary_52$TOTAL.B
M <- flu_summary_52$YEAR_WEEK

data=data.frame(B,A)
colors <- c("green","yellow")

# Plot the bar chart 
#barplot(H,names.arg=M,xlab="Month",ylab="Revenue",col="yellow",
#main="Influenza national summary ",ylim=range(0,10000),space=0)


barplot(as.matrix(as.data.frame(t(data))),beside=F,xlab="Week",names.arg=M, col=colors,axis.lty="solid",
       ylim=c(0,25000),ylab="Number of positive specimens",main="Influenza national summary by US Clinical Labs-52 Weeks")
#legend("topright",rownames(t(data)),fill=colors,title="Influenza national summary")
par(new=T)
#plot(flu_summary$Percent.Positive.A,type = 'o')

plot(flu_summary_52$PERCENT.POSITIVE, col="black", type="l", ylim=c(0,30), ylab="" ,xaxt="n",yaxt="n",
    xlab="")

# second y-axis
axis(4, cex.axis=0.8, tick=FALSE, adj =.04, line = -1.2)
mtext("Percent Positive", side = 4, line = 1.25)

par(new=T)
lines(flu_summary_52$PERCENT.A, col="#FF9933", type="l", lty=2,lwd=2, ylim=c(0,30), xlab="", ylab="" ,xaxt="n",yaxt="n")
par(new=T)
lines(flu_summary_52$PERCENT.B, col="green", type="l", lty=2,lwd=2, ylim=c(0,30), xlab="", ylab="" ,xaxt="n",yaxt="n")

legend("topright", bty="n", c("A","B"), fill=c("yellow","chartreuse3"), inset=c(.1,.001))
legend("topright", bty="n", c("Percent Positive","% Positive Flu A", "% Positive Flu A"), lty=c(1,2,2),lwd=c(1,2,2), col=c("black","darkgoldenrod2","chartreuse4"), inset=c(.1,.1))
# Out:
# Plot with title “Influenza national summary by US Clinical Labs-52 Weeks”

# %% [markdown]
# ### 2) Influenza Positive Tests Reported-52 Weeks

# %%
positive52 <- read.csv("FluViewPhase2Data/WHO_NREVSS_Public_Health_Labs.csv")
positive52$YEAR_WEEK <- paste(positive52$YEAR,positive52$WEEK)
positive52$YEAR_WEEK <- gsub('\\s+', '', positive52$YEAR_WEEK)

# %%
# Create the data for the chart
A2 <- positive52$A..Subtyping.not.Performed.
B2 <- positive52$A..2009.H1N1.
C2 <- positive52$A..H3.
M2 <- positive52$YEAR_WEEK
data2=data.frame(C2,B2,A2)
colors <- c("red","orange","yellow")



barplot(as.matrix(as.data.frame(t(data2))),beside=F,xlab="Week",names.arg=M2, col=colors,axis.lty="solid",
       ylim=range(0,3500),ylab="Number of positive specimens",main="Influenza Positive Test Report-52 WEEKS")


par(new=T)
barplot(positive52$H3N2v,col="purple",ylim=c(0,3500),xlab="Week",ylab="",names.arg=M2)

par(new=T)
barplot(positive52$BYam,col="chartreuse4",ylim=c(0,3500),xlab="Week",ylab="",names.arg=M2)

par(new=T)
barplot(positive52$B,col="darkgreen",ylim=c(0,3500),xlab="Week",ylab="",names.arg=M2)

par(new=T)
barplot(positive52$BVic,col="chartreuse",ylim=c(0,3500),xlab="Week",ylab="",names.arg=M2)



#par(new=T)
#barplot(positive52$BYam,col="chartreuse4",ylim=c(0,3500),xlab="Week",ylab="",names.arg=M2)

legend("topright", bty="n", c("A (Subtyping not performed)","(H1N1)pdm09","A(H3N2)","H3N2v","B(lineage not performed)",
                             "B(Victoria Lineage)","B(Yamgata Lineage)"), fill=c("yellow","orange",
                                                                                "red","purple",
                                                                                "darkgreen","chartreuse"
                                                                                ,"chartreuse4"),inset=c(.1,.001))
# Out:
# Plot with title “Influenza Positive Test Report-52 WEEKS”

# %% [markdown]
# # SOLUTION 6
# ## Influenza national summary (green and yellow chart) -NEW YORK-52 WEEKS

# %%
flu_summary_NY52 <- read.csv("Clinical_NY_52.csv")

flu_summary_NY52$YEAR_WEEK <- paste(flu_summary_NY52$YEAR,flu_summary_NY52$WEEK)
flu_summary_NY52$YEAR_WEEK <- gsub('\\s+', '', flu_summary_NY52$YEAR_WEEK)

# %%
# Create the data for the chart
A <- flu_summary_NY52$TOTAL.A
B <- flu_summary_NY52$TOTAL.B
M <- flu_summary_NY52$YEAR_WEEK

data=data.frame(B,A)
colors <- c("green","yellow")

# Plot the bar chart 
#barplot(H,names.arg=M,xlab="Month",ylab="Revenue",col="yellow",
#main="Influenza national summary ",ylim=range(0,10000),space=0)


barplot(as.matrix(as.data.frame(t(data))),beside=F,xlab="Week",names.arg=M, col=colors,axis.lty="solid",
       ylim=c(0,3000),ylab="Number of positive specimens",main="Influenza national summary by US Clinical Labs-New York : 52 Weeks")
#legend("topright",rownames(t(data)),fill=colors,title="Influenza national summary")
par(new=T)
#plot(flu_summary$Percent.Positive.A,type = 'o')

plot(flu_summary_NY52$PERCENT.POSITIVE, col="black", type="l", ylim=c(0,35), ylab="" ,xaxt="n",yaxt="n",
    xlab="")

# second y-axis
axis(4, cex.axis=0.8, tick=FALSE, adj =.04, line = -1.2)
mtext("Percent Positive", side = 4, line = 1.25)

par(new=T)
lines(flu_summary_NY52$PERCENT.A, col="#FF9933", type="l", lty=2,lwd=2, ylim=c(0,35), xlab="", ylab="" ,xaxt="n",yaxt="n")
par(new=T)
lines(flu_summary_NY52$PERCENT.B, col="green", type="l", lty=2,lwd=2, ylim=c(0,35), xlab="", ylab="" ,xaxt="n",yaxt="n")

legend("topright", bty="n", c("A","B"), fill=c("yellow","chartreuse3"), inset=c(.1,.001))
legend("topright", bty="n", c("Percent Positive","% Positive Flu A", "% Positive Flu A"), lty=c(1,2,2),lwd=c(1,2,2), col=c("black","darkgoldenrod2","chartreuse4"), inset=c(.1,.1))
# Out:
# Plot with title “Influenza national summary by US Clinical Labs-New York : 52 Weeks”
